# %%
import pandas as pd, numpy as np
from anticipy import forecast, forecast_models, forecast_plot

df = pd.DataFrame({'y': np.full(20,10.0)+np.random.normal(0.0, 0.1, 20),
                   'date':pd.date_range('2018-01-01', periods=20, freq='D')})
df_forecast = forecast.run_forecast(df, extrapolate_years=0.5)
df_forecast.tail(3)
# Out:
#           date source  is_actuals        model          y        q5  \
# 212 2018-07-19    src       False  snaive_wday   9.951146  9.632514
# 213 2018-07-20    src       False  snaive_wday   9.965313  9.648129
# 214 2018-07-21    src       False  snaive_wday  10.212386  9.772816
#
#            q95        q20        q80
# 212  10.223280   9.764427  10.098747
# 213  10.217539   9.795480  10.078570
# 214  10.486916  10.000024  10.358322

# %%
df = pd.DataFrame({'y': np.arange(0., 5)}, index=pd.date_range('2018-01-01', periods=5, freq='D'))
df_forecast = forecast.run_forecast(df, extrapolate_years=1)
df_forecast.head(12)
# Out:
# No forecast data for source src
#         date source  is_actuals    model    y
# 0 2018-01-01    src        True  actuals  0.0
# 1 2018-01-02    src        True  actuals  1.0
# 2 2018-01-03    src        True  actuals  2.0
# 3 2018-01-04    src        True  actuals  3.0
# 4 2018-01-05    src        True  actuals  4.0

# %%
path_tutorial_plot = 'plot-tutorial'

# Save plot as a file
# forecast_plot.plot_forecast(df_forecast, output='html', path=path_tutorial_plot, width=350, height=240, title='Tutorial Forecast')

# forecast_plot.plot_forecast(df_forecast, output='jupyter', width=350, height=240, title='Tutorial Forecast')
forecast_plot.plot_forecast(df_forecast, output='jupyter')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="c22a0fdc-b96b-453b-b2ba-98b4a9742e05" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c22a0fdc-b96b-453b-b2ba-98b4a9742e05")) {
#                     Plotly.newPlot(
#                         'c22a0fdc-b96b-453b-b2ba-98b4a9742e05',
#                         [{"hovertemplate": "%{x|%Y-%m-%d} : %{y:.4g}", "legendgroup": "actuals", "line": {"color": "rgba(0,191,196,0.2)"}, "marker": {"color": "rgba(0,191,196,0.9)", "size": 3}, "mode": "lines+markers", "name": "Actuals", "opacity": 0.8, "showlegend": true, "type": "scatter", "x": ["2018-01-01T00:00:00", "2018-01-02T00:00:00", "2018-01-03T00:00:00", "2018-01-04T00:00:00", "2018-01-05T00:00:00", "2018-01-06T00:00:00", "2018-01-07T00:00:00", "2018-01-08T00:00:00", "2018-01-09T00:00:00", "2018-01-10T00:00:00", "2018-01-11T00:00:00", "2018-01-12T00:00:00", "2018-01-13T00:00:00", "2018-01-14T00:00:00", "2018-01-15T00:00:00", "2018-01-16T00:00:00", "2018-01-17T00:00:00", "2018-01-18T00:00:00", "2018-01-19T00:00:00", "2018-01-20T00:00:00"], "xaxis": "x", "y": [10.08880617271997, 10.05142909558791, 9.929627307263987, 9.910178723744407, 9.99059321037782, 9.980760909973439, 10.18010491967692, 9.905142466700223, 10.097741924026725, 10.045043278715506, 9.891119707868357, 10.139629807059022, 10.042687221656674, 10.1305921325941, 9.894399299043044, 9.79122522595111, 9.918230680765761, 9.951145702766539, 9.9653134205539, 10.212386397407117], "yaxis": "y"}, {"hovertemplate": "%{x|%Y-%m-%d} : %{y:.4g}", "legendgroup": "forecast", "line": {"color": "rgba(248,118,109,0.4)", "width": 1}, "marker": {"color": "rgba(248,118,109,0.9)", "size": 3}, "mode": "lines+markers", "name": "Forecast", "showlegend": true, "type": "scatter", "x": ["2018-01-08T00:00:00", "2018-01-09T00:00:00", "2018-01-10T00:00:00", "2018-01-11T00:00:00", "2018-01-12T00:00:00", "2018-01-13T00:00:00", "2018-01-14T00:00:00", "2018-01-15T00:00:00", "2018-01-16T00:00:00", "2018-01-17T00:00:00", "2018-01-18T00:00:00", "2018-01-19T00:00:00", "2018-01-20T00:00:00", "2018-01-21T00:00:00", "2018-01-22T00:00:00", "2018-01-23T00:00:00", "2018